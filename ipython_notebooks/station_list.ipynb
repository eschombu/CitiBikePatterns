# %%
import numpy as np
from pandas import DataFrame, Series
import pandas as pd
from sklearn.decomposition import PCA
from datetime import date, datetime, timedelta
import time
from pytz import timezone
import pytz
import matplotlib.pyplot as plt

# %%
# Load Citi Bike data
CBmonths = np.array([np.array([np.ones((6,1))*2013, np.ones((6,1))*2014]).flatten(), \
    np.array([np.arange(7,13,1), np.arange(1,7,1)]).flatten()], dtype='int').T
mo_strs = []
for i in range(CBmonths.shape[0]):
    mo_strs.append(date(CBmonths[i,0], CBmonths[i,1], 1))

citibike_filename = "/home/vagrant/citibike/hourlyDB_" + mo_strs[0].strftime("%m-%Y") + \
    "_to_" + mo_strs[-1].strftime("%m-%Y") + ".csv.gz"
hourlyDF_bystart = pd.read_csv(citibike_filename, compression="gzip")

# %%
hourlyDF_bystart.head()
# Out:
#    startbin  start station id  end station id  total count  male count  \
# 0         1               116             247            1           0
# 1         1               128             128            1           0
# 2         1               143             391            1           1
# 3         1               146             161            1           0
# 4         1               146             351            1           1
#
#    female count  subscriber count  mean duration  mean age
# 0             0                 0            943       NaN
# 1             0                 0           1000       NaN
# 2             0                 1            185        17
# 3             0                 0            786       NaN
# 4             0                 1            456        38

# %%
CBcsv_filename = "/home/vagrant/citibike/trip_logs/citibikeDB_" \
    + mo_strs[0].strftime("%m-%Y") + "_to_" + mo_strs[-1].strftime("%m-%Y") + ".csv.gz"
tripDF = pd.read_csv(CBcsv_filename, compression="gzip")

# %%
tripDF.head()
# Out:
#    Unnamed: 0  tripduration            starttime             stoptime  \
# 0           0           634  2013-07-01 00:00:00  2013-07-01 00:10:34
# 1           1          1547  2013-07-01 00:00:02  2013-07-01 00:25:49
# 2           2           178  2013-07-01 00:01:04  2013-07-01 00:04:02
# 3           3          1580  2013-07-01 00:01:06  2013-07-01 00:27:26
# 4           4           757  2013-07-01 00:01:10  2013-07-01 00:13:47
#
#    start station id       start station name  start station latitude  \
# 0               164          E 47 St & 2 Ave               40.753231
# 1               388         W 26 St & 10 Ave               40.749718
# 2               293    Lafayette St & E 8 St               40.730287
# 3               531   Forsyth St & Broome St               40.718939
# 4               382  University Pl & E 14 St               40.734927
#
#    start station longitude  end station id         end station name  \
# ...

# %%
a = tripDF.groupby("start station id")["start station id", "start station name", "start station latitude", \
    "start station longitude"].first()
a.columns = ["station id", "station name", "station latitude", "station longitude"]
print a.shape
a.head()
# Out:
# (332, 4)
#                   station id                   station name  station latitude  \
# start station id
# 72                        72               W 52 St & 11 Ave         40.767272
# 79                        79       Franklin St & W Broadway         40.719116
# 82                        82         St James Pl & Pearl St         40.711174
# 83                        83  Atlantic Ave & Fort Greene Pl         40.683826
# 116                      116                W 17 St & 8 Ave         40.741776
#
#                   station longitude
# start station id
# 72                       -73.993929
# 79                       -74.006667
# 82                       -74.000165
# 83                       -73.976323
# 116                      -74.001497

# %%
b = tripDF.groupby("end station id")["end station id", "end station name", "end station latitude", \
    "end station longitude"].first()
b.columns = ["station id", "station name", "station latitude", "station longitude"]
print b.shape
b.head()
# Out:
# (332, 4)
#                 station id                   station name  station latitude  \
# end station id
# 72                      72               W 52 St & 11 Ave         40.767272
# 79                      79       Franklin St & W Broadway         40.719116
# 82                      82         St James Pl & Pearl St         40.711174
# 83                      83  Atlantic Ave & Fort Greene Pl         40.683826
# 116                    116                W 17 St & 8 Ave         40.741776
#
#                 station longitude
# end station id
# 72                     -73.993929
# 79                     -74.006667
# 82                     -74.000165
# 83                     -73.976323
# 116                    -74.001497

# %%
station_df = pd.merge(a, b, how='outer').set_index("station id")
print station_df.shape
station_df.head()
# Out:
# (332, 3)
#                              station name  station latitude  station longitude
# station id
# 72                       W 52 St & 11 Ave         40.767272         -73.993929
# 79               Franklin St & W Broadway         40.719116         -74.006667
# 82                 St James Pl & Pearl St         40.711174         -74.000165
# 83          Atlantic Ave & Fort Greene Pl         40.683826         -73.976323
# 116                       W 17 St & 8 Ave         40.741776         -74.001497

# %%
station_file = open("/home/vagrant/citibike/station_list.csv", 'w')
station_df.to_csv(station_file)

# %%
station_file.close()
